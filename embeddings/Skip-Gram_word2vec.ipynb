# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random
drop_thresh = 1e-05
w_count = Counter(int_words)
w_freq = {word:count/len(int_words) for word,count in w_count.items()}
p_drop = {word:1-np.sqrt(drop_thresh/w_freq[word]) for word in w_count}

train_words =[word for word in int_words if p_drop[word]<random.random()] # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    
    # Your code here
    r = np.random.randint(1,window_size+1)
    start_idx = 0
    end_idx = len(words)
    
    if idx - r > 0:
        start_idx = idx - r
    
    if idx + r < end_idx:
        end_idx=idx+r
#     print('start: ', start_idx)
#     print('stop: ', end_idx)
    target_words = set(words[start_idx:idx] + words[idx+1:end_idx+1])    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,shape=[None])
    labels = tf.placeholder(tf.int32, shape=(None,None))

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
print("n_vocab: ", n_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform(minval =-1,maxval=1,shape=(n_vocab, n_embedding)))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output
# Out:
# n_vocab:  63641

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab,n_embedding),stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b,
                                      labels,embed,
                                      n_sampled,n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-12-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6574 0.0158 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6241 0.0142 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5063 0.0137 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6121 0.0141 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5262 0.0140 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5590 0.0140 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5608 0.0130 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5599 0.0138 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4722 0.0141 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4115 0.0144 sec/batch
# Nearest to an: shareholder, magnetically, from, hodge, mszp, weyl, lexemes, limes,
# Nearest to it: stallman, athaliah, multiplexed, telomere, prohibit, secretions, temptation, sentai,
# Nearest to as: microorganisms, ammonites, rel, vistula, stunning, additions, three, byzantine,
# Nearest to history: olde, desserts, aptitude, admirative, surrealistic, dll, alto, martindale,
# Nearest to he: differentiable, qutb, waking, psara, mommy, thorny, had, lac,
# Nearest to world: baths, trajectories, emboldened, guilder, doubleday, tutte, prasad, qwest,
# Nearest to s: voodoo, disappearances, cagliari, mev, borland, slugged, faces, arbuckle,
# Nearest to a: europeans, petrov, mammalia, nemanja, loyal, feuds, developments, stabat,
# Nearest to applications: stakes, utub, maniera, manage, nicholson, coursework, vogel, conventionally,
# Nearest to orthodox: greyface, jm, snell, agnew, werner, pushed, calc, noriega,
# Nearest to brother: frown, gawain, explicated, cascades, hawkeye, wels, ircs, popolare,
# Nearest to centre: reliability, neuropsychological, pliny, fcc, judaism, criticizes, labor, versed,
# Nearest to know: hinder, cherry, hieroglyph, prettiest, drones, foursome, brownstone, pik,
# Nearest to notes: stoic, propounded, pires, twice, feasts, television, smelt, teutoburg,
# Nearest to older: rit, nger, posses, left, gamemaster, clients, esquivel, injector,
# Nearest to running: lu, generically, tier, chao, eristic, latch, minter, maccabeus,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5060 0.0139 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4264 0.0133 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3174 0.0139 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2558 0.0135 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2074 0.0144 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1437 0.0132 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1030 0.0142 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0601 0.0151 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9892 0.0147 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9717 0.0134 sec/batch
# Nearest to an: from, shareholder, magnetically, taiwan, engineering, drum, hodge, mszp,
# Nearest to it: cycles, prohibit, english, telomere, athaliah, stallman, temptation, st,
# Nearest to as: microorganisms, hours, ammonites, stunning, style, rel, impractical, software,
# Nearest to history: olde, desserts, vital, sleep, recreation, creed, athletic, notation,
# Nearest to he: differentiable, had, dark, employ, waking, up, qutb, psara,
# Nearest to world: mouth, distinguished, try, mexico, baths, trajectories, reverse, declined,
# Nearest to s: voodoo, faces, disappearances, cagliari, latin, sex, joke, mev,
# Nearest to a: on, europeans, produces, readily, occurs, loyal, developments, loss,
# Nearest to applications: stakes, manage, utub, general, nicholson, affects, document, maniera,
# Nearest to orthodox: snell, greyface, pushed, werner, noriega, firing, jm, simplifications,
# Nearest to brother: gawain, frown, explicated, kong, ircs, wels, hawkeye, cascades,
# Nearest to centre: reliability, judaism, labor, neuropsychological, pliny, fcc, objectives, criticizes,
# Nearest to know: hinder, hieroglyph, cherry, prettiest, buy, resultant, neighbors, enhanced,
# Nearest to notes: television, twice, faq, stoic, pires, propounded, smelt, feasts,
# Nearest to older: left, rit, nger, posses, nothing, power, pinch, clients,
# Nearest to running: lu, studied, tier, chao, generically, simultaneously, cards, coil,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9519 0.0142 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8987 0.0140 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8461 0.0138 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8803 0.0140 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8220 0.0135 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8132 0.0151 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8122 0.0145 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7889 0.0139 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7674 0.0136 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7852 0.0139 sec/batch
# Nearest to an: weyl, magnetically, shareholder, taiwan, mszp, concluded, syracuse, engineering,
# Nearest to it: stallman, prohibit, cycles, temptation, telomere, athaliah, warmer, propagate,
# Nearest to as: microorganisms, stunning, ammonites, vistula, rel, impractical, hours, storyline,
# Nearest to history: olde, vital, desserts, creed, athletic, dll, alto, aptitude,
# Nearest to he: differentiable, fate, had, waking, up, predates, rallying, expedient,
# Nearest to world: declined, mouth, trajectories, emboldened, distinguished, baths, doubleday, tutte,
# Nearest to s: voodoo, disappearances, joke, faces, cagliari, sex, clue, loser,
# Nearest to a: produces, remedy, on, feuds, europeans, merger, readily, heavens,
# Nearest to applications: stakes, manage, utub, conventionally, confirm, curriculum, nicholson, affects,
# Nearest to orthodox: snell, greyface, werner, firing, pushed, noriega, jm, blica,
# Nearest to brother: frown, gawain, lowlands, kong, explicated, cascades, hawkeye, assistance,
# Nearest to centre: reliability, pliny, labor, neuropsychological, fcc, judaism, objectives, criticizes,
# Nearest to know: hinder, hieroglyph, resultant, cherry, foundational, fade, prettiest, closeup,
# Nearest to notes: television, twice, stoic, faq, propounded, greens, feasts, pires,
# Nearest to older: rit, left, clients, posses, nger, gamemaster, power, enlightened,
# Nearest to running: lu, generically, studied, synopsis, ninth, tier, cards, simultaneously,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7674 0.0142 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7322 0.0139 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7268 0.0138 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6994 0.0136 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7842 0.0136 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7033 0.0138 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6974 0.0138 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7414 0.0134 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6951 0.0142 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6542 0.0143 sec/batch
# Nearest to an: weyl, magnetically, syracuse, shareholder, mszp, showa, concluded, taiwan,
# Nearest to it: prohibit, stallman, temptation, troublesome, telomere, cycles, confrontational, warmer,
# Nearest to as: microorganisms, vistula, ammonites, stunning, rel, hours, style, impractical,
# Nearest to history: olde, aptitude, dll, monophysite, vital, athletic, creed, desserts,
# Nearest to he: differentiable, had, expedient, predates, waking, mommy, fate, qutb,
# Nearest to world: doubleday, mouth, baths, declined, spoons, tutte, trajectories, emboldened,
# Nearest to s: voodoo, sex, disappearances, slugged, occured, cagliari, joke, mpaa,
# Nearest to a: feuds, produces, remedy, evan, merger, readily, on, heavens,
# Nearest to applications: stakes, manage, utub, conventionally, affects, imply, alleles, curriculum,
# Nearest to orthodox: snell, greyface, jm, werner, writings, firing, noriega, pushed,
# Nearest to brother: frown, gawain, lowlands, hawkeye, explicated, babylonian, ircs, cascades,
# Nearest to centre: pliny, labor, reliability, fcc, neuropsychological, objectives, versed, sherlock,
# Nearest to know: hinder, hieroglyph, foundational, cherry, resultant, fade, closeup, entities,
# Nearest to notes: stoic, propounded, twice, television, faq, feasts, pires, w,
# Nearest to older: rit, nger, left, posses, clients, interned, sinai, russians,
# Nearest to running: lu, generically, synopsis, cards, coil, studied, maccabeus, ninth,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7001 0.0144 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6349 0.0130 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6169 0.0134 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6313 0.0138 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6502 0.0140 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6261 0.0133 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5759 0.0101 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5765 0.0137 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4932 0.0142 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5016 0.0132 sec/batch
# Nearest to an: weyl, magnetically, lexemes, hodge, mszp, showa, intermarriages, limes,
# Nearest to it: prohibit, temptation, stallman, telomere, troublesome, bullwinkle, cycles, separated,
# Nearest to as: microorganisms, ammonites, vistula, stunning, rel, hours, style, unable,
# Nearest to history: dll, athletic, aptitude, olde, monophysite, spartacus, creed, alto,
# Nearest to he: had, differentiable, expedient, qutb, mommy, asked, fate, minoru,
# Nearest to world: mouth, doubleday, recruiting, tutte, baths, mexico, emboldened, mackaye,
# Nearest to s: voodoo, disappearances, slugged, occured, cried, sex, joke, mpaa,
# Nearest to a: feuds, produces, plutarch, compressible, on, heavens, occurs, can,
# Nearest to applications: stakes, alleles, affects, manage, superhighway, surges, utub, conventionally,
# Nearest to orthodox: snell, greyface, jm, writings, calc, noriega, blica, penicillin,
# Nearest to brother: frown, hawkeye, gawain, cascades, explicated, ircs, lowlands, babylonian,
# Nearest to centre: pliny, labor, reliability, fcc, neuropsychological, objectives, hinterland, versed,
# Nearest to know: foundational, hinder, closeup, hieroglyph, fade, brownstone, resultant, cherry,
# Nearest to notes: stoic, propounded, pires, faq, w, television, feasts, twice,
# Nearest to older: rit, posses, nger, left, clients, gamemaster, rescheduling, subregions,
# Nearest to running: lu, generically, maccabeus, coil, cards, simultaneously, synopsis, minter,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4898 0.0141 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5005 0.0135 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4701 0.0142 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4948 0.0137 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5394 0.0136 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4919 0.0142 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4550 0.0137 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4080 0.0137 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4322 0.0145 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4338 0.0136 sec/batch
# Nearest to an: weyl, magnetically, lexemes, hodge, showa, mszp, intermarriages, concluded,
# Nearest to it: prohibit, temptation, cycles, stallman, separated, troublesome, bullwinkle, telomere,
# Nearest to as: microorganisms, vistula, stunning, ammonites, rel, style, unable, hours,
# Nearest to history: athletic, spartacus, dll, monophysite, creed, aptitude, aegeas, letters,
# Nearest to he: had, asked, expedient, fate, qutb, mary, mommy, differentiable,
# Nearest to world: mouth, doubleday, mackaye, tendency, recruiting, baths, emboldened, deportations,
# Nearest to s: voodoo, slugged, disappearances, mpaa, voyager, joke, occured, sex,
# Nearest to a: produces, feuds, can, compressible, object, occurs, geocentric, intramolecular,
# Nearest to applications: stakes, alleles, affects, x, superhighway, surges, manage, computers,
# Nearest to orthodox: catholic, greyface, writings, snell, christianity, jm, religious, penicillin,
# Nearest to brother: frown, explicated, gawain, hawkeye, cascades, daughter, ircs, fleeing,
# Nearest to centre: pliny, labor, reliability, fcc, hinterland, neuropsychological, arundel, objectives,
# Nearest to know: foundational, hinder, closeup, brownstone, rousseau, cherry, prettiest, fade,
# Nearest to notes: stoic, propounded, faq, pires, w, smelt, feasts, twice,
# Nearest to older: rit, posses, nger, left, gamemaster, subregions, rescheduling, macarius,
# Nearest to running: lu, generically, maccabeus, cards, stereotyping, coil, simultaneously, minter,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4436 0.0140 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4287 0.0138 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4133 0.0137 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3677 0.0141 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4047 0.0137 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4344 0.0138 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3696 0.0141 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3867 0.0140 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4278 0.0140 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3805 0.0137 sec/batch
# Nearest to an: magnetically, weyl, lexemes, hodge, showa, a, intermarriages, mszp,
# Nearest to it: separated, prohibit, telomere, cycles, multiplexed, troublesome, confrontational, stallman,
# Nearest to as: microorganisms, vistula, rel, ammonites, stunning, jocular, style, protoscience,
# Nearest to history: athletic, spartacus, monophysite, dll, creed, olde, empire, aptitude,
# Nearest to he: had, asked, fate, expedient, mary, qutb, mommy, historicity,
# Nearest to world: mouth, doubleday, tendency, recruiting, mackaye, baths, emboldened, ingmar,
# Nearest to s: voodoo, slugged, voyager, joke, hometown, disappearances, mpaa, occured,
# Nearest to a: feuds, compressible, can, on, produces, object, geocentric, readily,
# Nearest to applications: stakes, alleles, affects, manage, computers, conventionally, surges, coursework,
# Nearest to orthodox: catholic, christianity, greyface, writings, religious, penicillin, jm, noriega,
# Nearest to brother: frown, daughter, gawain, explicated, cascades, hawkeye, ircs, milarepa,
# Nearest to centre: pliny, labor, reliability, fcc, hinterland, mined, neuropsychological, rococo,
# Nearest to know: foundational, hinder, closeup, rousseau, brownstone, prettiest, fade, cherry,
# Nearest to notes: stoic, faq, pires, w, propounded, textus, twice, television,
# Nearest to older: rit, posses, gamemaster, left, subregions, macarius, mistranslation, occupancy,
# Nearest to running: lu, generically, cards, stereotyping, simultaneously, maccabeus, minter, unauthorised,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3916 0.0141 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4128 0.0133 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3422 0.0132 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3670 0.0133 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3726 0.0138 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3662 0.0137 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3820 0.0137 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3661 0.0135 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3553 0.0137 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3625 0.0140 sec/batch
# Nearest to an: magnetically, weyl, lexemes, a, intermarriages, hodge, from, shrunken,
# Nearest to it: troublesome, separated, prohibit, telomere, cycles, slit, multiplexed, to,
# Nearest to as: microorganisms, rel, ammonites, vistula, bottleneck, stunning, macroscopic, jocular,
# Nearest to history: athletic, language, wickham, spartacus, monophysite, empire, culture, creed,
# Nearest to he: had, asked, expedient, fate, mommy, mattie, him, kamenev,
# Nearest to world: doubleday, tendency, mouth, recruiting, mackaye, declined, deportations, sulfates,
# Nearest to s: voodoo, disappearances, hometown, joke, occured, mpaa, sex, shasta,
# Nearest to a: compressible, feuds, object, can, on, an, produces, geocentric,
# Nearest to applications: stakes, manage, affects, redundancy, alleles, computers, surges, conventionally,
# Nearest to orthodox: catholic, christianity, religious, greyface, writings, nicaea, penicillin, jm,
# Nearest to brother: frown, daughter, explicated, gawain, ircs, cascades, widow, hawkeye,
# Nearest to centre: pliny, reliability, labor, fcc, hinterland, mined, neuropsychological, rococo,
# Nearest to know: foundational, closeup, rousseau, fade, hinder, brownstone, prettiest, get,
# Nearest to notes: stoic, faq, pires, propounded, w, textus, twice, feasts,
# Nearest to older: rit, posses, rescheduling, gamemaster, macarius, milvian, mistranslation, subregions,
# Nearest to running: lu, generically, cards, minter, unauthorised, maccabeus, simultaneously, synopsis,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3348 0.0138 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2986 0.0134 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3656 0.0137 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3647 0.0133 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3920 0.0135 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2954 0.0137 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3112 0.0135 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3210 0.0137 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2221 0.0135 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2906 0.0137 sec/batch
# Nearest to an: magnetically, lexemes, a, weyl, hodge, lathes, mszp, tokai,
# Nearest to it: prohibit, troublesome, slit, telomere, separated, multiplexed, shelves, sequestration,
# Nearest to as: microorganisms, rel, macroscopic, ammonites, vistula, jocular, bottleneck, stunning,
# Nearest to history: athletic, language, wickham, spartacus, yad, monophysite, empire, parkes,
# Nearest to he: had, asked, expedient, stint, worthy, kamenev, mattie, fate,
# Nearest to world: recruiting, tendency, doubleday, mouth, mackaye, declined, outlying, deportations,
# Nearest to s: voodoo, sex, hometown, disappearances, slugged, occured, borland, mpaa,
# Nearest to a: compressible, object, can, an, feuds, on, produces, vaud,
# Nearest to applications: manage, stakes, computers, alleles, redundancy, affects, conventionally, aspergillus,
# Nearest to orthodox: catholic, christianity, religious, greyface, writings, nicaea, theocracy, jm,
# Nearest to brother: frown, daughter, explicated, gawain, ircs, widow, cascades, hawkeye,
# Nearest to centre: pliny, reliability, mined, labor, fcc, hinterland, arundel, overlooks,
# Nearest to know: foundational, closeup, brownstone, fade, get, rousseau, whatever, ourselves,
# Nearest to notes: stoic, faq, propounded, pires, w, textus, robbins, turing,
# Nearest to older: rit, posses, rescheduling, milvian, mistranslation, macarius, gamemaster, subregions,
# Nearest to running: lu, cards, generically, minter, unauthorised, maccabeus, contract, synopsis,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2841 0.0143 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2968 0.0133 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3239 0.0062 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2452 0.0132 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2116 0.0134 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2246 0.0137 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2399 0.0137 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2129 0.0135 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2327 0.0137 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1686 0.0139 sec/batch
# Nearest to an: magnetically, a, lexemes, weyl, hodge, lathes, trivial, acid,
# Nearest to it: separated, shelves, prohibit, to, troublesome, telomere, multiplexed, cycles,
# Nearest to as: microorganisms, jocular, ammonites, rel, vistula, macroscopic, viru, undernourished,
# Nearest to history: athletic, spartacus, language, yad, weblog, wickham, linguistic, hosts,
# Nearest to he: had, asked, worthy, fate, him, expedient, qutb, kamenev,
# Nearest to world: recruiting, doubleday, tendency, mouth, mackaye, outlying, declined, ingmar,
# Nearest to s: sex, disappearances, voodoo, hometown, slugged, shasta, voyager, occured,
# Nearest to a: compressible, an, on, feuds, vaud, object, iix, produces,
# Nearest to applications: manage, stakes, avionics, redundancy, aspergillus, alleles, thumbnail, execute,
# Nearest to orthodox: catholic, christianity, greyface, religious, writings, preserved, nicaea, noriega,
# Nearest to brother: frown, daughter, explicated, ircs, gawain, widow, cascades, beloved,
# Nearest to centre: pliny, reliability, mined, hinterland, fcc, labor, geopolitical, overlooks,
# Nearest to know: foundational, brownstone, fade, closeup, myself, get, ourselves, prettiest,
# Nearest to notes: faq, stoic, pires, textus, propounded, w, robbins, ensembles,
# Nearest to older: rit, posses, mistranslation, macarius, rescheduling, householder, milvian, spoken,
# Nearest to running: lu, generically, cards, minter, unauthorised, maccabeus, simultaneously, stereotyping,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2294 0.0142 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2289 0.0138 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2415 0.0140 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1343 0.0135 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1889 0.0139 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1478 0.0143 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1788 0.0135 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2031 0.0133 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2112 0.0135 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1793 0.0134 sec/batch
# Nearest to an: magnetically, a, lexemes, weyl, hodge, trivial, lathes, from,
# Nearest to it: troublesome, prohibit, to, separated, sequestration, telomere, shelves, fallopian,
# Nearest to as: microorganisms, jocular, ammonites, rel, for, macroscopic, flexi, unique,
# Nearest to history: athletic, hosts, weblog, spartacus, readme, language, wickham, yad,
# Nearest to he: had, asked, expedient, him, fate, stint, worthy, qutb,
# Nearest to world: tendency, recruiting, doubleday, mackaye, cricinfo, mouth, ingmar, sulfates,
# Nearest to s: voodoo, sex, borland, disappearances, slugged, hometown, shasta, lockhart,
# Nearest to a: compressible, an, can, object, vaud, on, iix, feuds,
# Nearest to applications: execute, manage, general, aspergillus, avionics, redundancy, alleles, coursework,
# Nearest to orthodox: catholic, christianity, greyface, religious, apostolic, nicaea, theocracy, writings,
# Nearest to brother: frown, daughter, ircs, widow, explicated, gawain, hawkeye, beloved,
# Nearest to centre: reliability, pliny, mined, hinterland, fcc, labor, geopolitical, descend,
# Nearest to know: foundational, get, myself, brownstone, ourselves, fade, closeup, whatever,
# Nearest to notes: faq, stoic, propounded, textus, pires, w, robbins, normanby,
# Nearest to older: rit, householder, posses, mistranslation, macarius, versus, rescheduling, milvian,
# Nearest to running: lu, cards, minter, generically, unauthorised, contract, simultaneously, samsung,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1733 0.0138 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2366 0.0131 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1596 0.0136 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1419 0.0138 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1697 0.0139 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2216 0.0138 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2116 0.0134 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1594 0.0137 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1448 0.0139 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1764 0.0141 sec/batch
# Nearest to an: magnetically, a, lexemes, weyl, from, trivial, lathes, erlang,
# Nearest to it: prohibit, fallopian, troublesome, sequestration, sections, telomere, cycles, rstendamm,
# Nearest to as: microorganisms, macroscopic, jocular, ammonites, for, rel, linearity, protoscience,
# Nearest to history: athletic, hosts, readme, yad, weblog, spartacus, wickham, monophysite,
# Nearest to he: had, stint, asked, him, fate, noticed, expedient, winchilsea,
# Nearest to world: tendency, doubleday, recruiting, cricinfo, mackaye, sulfates, ingmar, mouth,
# Nearest to s: sex, voodoo, disappearances, shasta, lockhart, promoting, hometown, slugged,
# Nearest to a: compressible, an, vaud, iix, feuds, on, object, can,
# Nearest to applications: manage, general, coursework, document, aspergillus, thumbnail, stakes, superhighway,
# Nearest to orthodox: catholic, greyface, christianity, religious, nicaea, theocracy, rallied, noriega,
# Nearest to brother: frown, daughter, ircs, widow, explicated, gawain, dream, beloved,
# Nearest to centre: reliability, pliny, mined, hinterland, fcc, labor, geopolitical, descend,
# Nearest to know: foundational, myself, get, brownstone, whatever, fade, ourselves, closeup,
# Nearest to notes: faq, pires, textus, stoic, w, propounded, robbins, normanby,
# Nearest to older: rit, householder, mistranslation, versus, posses, household, macarius, milvian,
# Nearest to running: minter, unauthorised, lu, cards, generically, contract, samsung, overstepped,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1676 0.0139 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1322 0.0136 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1744 0.0132 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2085 0.0132 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1405 0.0134 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1230 0.0139 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1804 0.0136 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1265 0.0138 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2151 0.0137 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1953 0.0135 sec/batch
# Nearest to an: magnetically, a, lexemes, weyl, mahommed, herodian, lathes, concluded,
# Nearest to it: prohibit, troublesome, sequestration, fallopian, to, rstendamm, enthusiasm, sections,
# Nearest to as: microorganisms, for, rel, ammonites, jocular, deems, vistula, greg,
# Nearest to history: athletic, readme, wickham, weblog, hosts, monophysite, yad, linguistic,
# Nearest to he: had, stint, mattie, expedient, him, qutb, lansbury, winchilsea,
# Nearest to world: doubleday, recruiting, tendency, cricinfo, ramakrishna, neustadt, sulfates, mackaye,
# Nearest to s: lockhart, voodoo, sex, hometown, slugged, promoting, disappearances, shasta,
# Nearest to a: vaud, an, iix, feuds, on, compressible, petrov, prum,
# Nearest to applications: manage, general, coursework, aspergillus, thumbnail, apps, debug, superhighway,
# Nearest to orthodox: catholic, greyface, christianity, religious, circumcision, rallied, jm, preserved,
# Nearest to brother: daughter, frown, ircs, widow, beloved, explicated, son, gawain,
# Nearest to centre: reliability, pliny, mined, fcc, hinterland, labor, overlooks, descend,
# Nearest to know: foundational, myself, get, brownstone, you, whatever, ourselves, fade,
# Nearest to notes: faq, pires, textus, stoic, propounded, normanby, w, robbins,
# Nearest to older: householder, rit, household, posses, mistranslation, versus, families, milvian,
# Nearest to running: minter, unauthorised, lu, contract, youngest, samsung, cards, generically,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2384 0.0139 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1419 0.0137 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1410 0.0136 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1489 0.0137 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0510 0.0139 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1614 0.0136 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1412 0.0139 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1275 0.0137 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1768 0.0029 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1364 0.0135 sec/batch
# Nearest to an: magnetically, a, lexemes, from, weyl, trivial, mauritians, lathes,
# Nearest to it: prohibit, rstendamm, to, fallopian, telomere, troublesome, up, sequestration,
# Nearest to as: microorganisms, for, macroscopic, flexi, jocular, rel, linearity, greg,
# Nearest to history: athletic, weblog, hosts, readme, wickham, spartacus, desserts, yad,
# Nearest to he: had, stint, him, expedient, mattie, kamenev, fate, qutb,
# Nearest to world: doubleday, recruiting, tendency, mackaye, neustadt, cricinfo, inspections, fao,
# Nearest to s: sex, lockhart, hometown, voodoo, disappearances, slugged, essentialist, voyager,
# Nearest to a: an, on, compressible, iix, vaud, oo, can, the,
# Nearest to applications: manage, general, coursework, apps, debug, thumbnail, superhighway, aspergillus,
# Nearest to orthodox: catholic, greyface, christianity, religious, rallied, circumcision, noriega, jm,
# Nearest to brother: daughter, frown, ircs, widow, beloved, explicated, marry, cascades,
# Nearest to centre: pliny, reliability, mined, hinterland, fcc, overlooks, geopolitical, descend,
# Nearest to know: foundational, myself, get, brownstone, you, ourselves, whatever, stairway,
# Nearest to notes: faq, textus, pires, propounded, stoic, w, normanby, robbins,
# Nearest to older: householder, rit, mistranslation, posses, families, household, versus, rescheduling,
# Nearest to running: minter, unauthorised, lu, contract, generically, samsung, activex, maccabeus,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0801 0.0140 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.1002 0.0141 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0965 0.0135 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0717 0.0131 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0842 0.0136 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0165 0.0137 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0976 0.0137 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1127 0.0143 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1418 0.0143 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0244 0.0140 sec/batch
# Nearest to an: a, magnetically, lexemes, from, concluded, embarrassingly, trivial, mauritians,
# Nearest to it: to, rstendamm, prohibit, sequestration, fallopian, cycles, separated, up,
# Nearest to as: microorganisms, for, macroscopic, flexi, jocular, unique, rel, of,
# Nearest to history: weblog, athletic, hosts, wickham, spartacus, empire, readme, aegeas,
# Nearest to he: had, him, stint, fate, expedient, qutb, noticed, mattie,
# Nearest to world: recruiting, doubleday, tendency, cricinfo, mackaye, cri, sulfates, neustadt,
# Nearest to s: sex, lockhart, shasta, promoting, guyana, hometown, slugged, voodoo,
# Nearest to a: an, iix, on, compressible, vaud, the, spins, of,
# Nearest to applications: general, manage, apps, coursework, thumbnail, debug, aspergillus, pda,
# Nearest to orthodox: greyface, catholic, circumcision, religious, rallied, noriega, christianity, jm,
# Nearest to brother: daughter, frown, ircs, widow, beloved, explicated, marry, son,
# Nearest to centre: pliny, reliability, mined, hinterland, fcc, now, overlooks, geopolitical,
# Nearest to know: myself, get, you, foundational, brownstone, ourselves, fade, toil,
# Nearest to notes: faq, textus, pires, ensembles, propounded, strings, sixths, octave,
# Nearest to older: householder, rit, household, versus, mistranslation, families, posses, macarius,
# Nearest to running: unauthorised, minter, esat, generically, lu, samsung, contract, overstepped,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0339 0.0137 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0182 0.0133 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0388 0.0133 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0818 0.0134 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0420 0.0134 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0480 0.0134 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0514 0.0135 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0975 0.0138 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0668 0.0134 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0291 0.0138 sec/batch
# Nearest to an: a, magnetically, lexemes, from, embarrassingly, trivial, weyl, boson,
# Nearest to it: to, fallopian, prohibit, cycles, troublesome, rstendamm, sequestration, telomere,
# Nearest to as: microorganisms, for, macroscopic, of, unique, jocular, rel, deems,
# Nearest to history: weblog, athletic, hosts, wickham, aegeas, readme, spartacus, empire,
# Nearest to he: had, stint, him, fate, winchilsea, heroically, mattie, lansbury,
# Nearest to world: doubleday, tendency, recruiting, cri, cricinfo, mackaye, deny, ramakrishna,
# Nearest to s: sex, lockhart, reprinting, voyager, voodoo, hometown, shasta, slugged,
# Nearest to a: an, iix, on, compressible, of, can, the, vaud,
# Nearest to applications: manage, general, apps, thumbnail, coursework, debug, pda, superhighway,
# Nearest to orthodox: catholic, greyface, christianity, circumcision, rallied, noriega, jm, trumped,
# Nearest to brother: daughter, ircs, frown, beloved, son, widow, explicated, gawain,
# Nearest to centre: reliability, pliny, mined, hinterland, fcc, overlooks, now, labor,
# Nearest to know: get, you, myself, foundational, brownstone, proves, whatever, ourselves,
# Nearest to notes: faq, textus, pires, stoic, chalukyas, propounded, robbins, sixths,
# Nearest to older: householder, household, versus, rit, families, mistranslation, posses, macarius,
# Nearest to running: minter, unauthorised, samsung, esat, lu, contract, linebackers, overstepped,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0608 0.0137 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0852 0.0138 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0915 0.0136 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0665 0.0133 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0675 0.0138 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0565 0.0135 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0637 0.0135 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0915 0.0139 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0818 0.0138 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0941 0.0134 sec/batch
# Nearest to an: a, magnetically, from, lexemes, herodian, mahommed, weyl, concluded,
# Nearest to it: prohibit, hermas, rstendamm, to, cycles, fallopian, since, troublesome,
# Nearest to as: for, microorganisms, of, ammonites, deems, by, cleansed, jocular,
# Nearest to history: weblog, empire, athletic, readme, aegeas, hosts, yad, koine,
# Nearest to he: had, him, stint, winchilsea, fate, lansbury, heroically, mattie,
# Nearest to world: tendency, doubleday, recruiting, deny, cri, cricinfo, tournament, sulfates,
# Nearest to s: lockhart, sex, shasta, promoting, guyana, voodoo, correspondents, stamps,
# Nearest to a: an, iix, of, on, vaud, the, spins, compressible,
# Nearest to applications: general, manage, coursework, apps, superhighway, thumbnail, aspergillus, pda,
# Nearest to orthodox: catholic, greyface, rallied, christianity, ecumenism, trumped, noriega, religious,
# Nearest to brother: daughter, frown, ircs, son, beloved, explicated, widow, marry,
# Nearest to centre: pliny, reliability, hinterland, mined, fcc, overlooks, now, labor,
# Nearest to know: you, get, myself, ll, foundational, proves, toil, brownstone,
# Nearest to notes: faq, textus, pires, stoic, propounded, chalukyas, normanby, w,
# Nearest to older: householder, household, rit, versus, families, mistranslation, posses, macarius,
# Nearest to running: minter, unauthorised, esat, samsung, lu, contract, maccabeus, uncontested,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0649 0.0136 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0125 0.0132 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0234 0.0138 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0927 0.0138 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0517 0.0135 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1297 0.0133 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1214 0.0136 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0211 0.0131 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0256 0.0132 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0526 0.0132 sec/batch
# Nearest to an: a, magnetically, from, lexemes, weyl, herodian, mahommed, and,
# Nearest to it: to, prohibit, troublesome, rstendamm, slit, sequestration, telomere, fallopian,
# Nearest to as: for, microorganisms, firefighters, deems, macroscopic, of, rel, by,
# Nearest to history: weblog, empire, athletic, aegeas, monophysite, readme, yad, spartacus,
# Nearest to he: had, stint, him, lansbury, winchilsea, hoffmann, freewheelin, graham,
# Nearest to world: doubleday, recruiting, tendency, cri, cricinfo, tournament, commemorative, fao,
# Nearest to s: sex, lockhart, correspondents, hometown, promoting, cultivated, slugged, guyana,
# Nearest to a: an, can, the, compressible, of, on, iix, spins,
# Nearest to applications: manage, general, coursework, thumbnail, apps, superhighway, pda, aspergillus,
# Nearest to orthodox: greyface, catholic, rallied, jm, trumped, noriega, ecumenism, hermaphrodite,
# Nearest to brother: daughter, ircs, frown, son, beloved, explicated, marry, widow,
# Nearest to centre: pliny, reliability, now, hinterland, fcc, mined, overlooks, ruins,
# Nearest to know: get, you, myself, proves, foundational, ll, toil, stairway,
# Nearest to notes: faq, textus, pires, octave, stoic, propounded, sixths, strings,
# Nearest to older: householder, household, families, versus, rit, posses, mistranslation, macarius,
# Nearest to running: minter, unauthorised, esat, contract, samsung, overstepped, maccabeus, linebackers,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9642 0.0141 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0255 0.0134 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0470 0.0136 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0232 0.0136 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0712 0.0135 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0440 0.0130 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0215 0.0134 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9768 0.0135 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0087 0.0141 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9801 0.0137 sec/batch
# Nearest to an: a, magnetically, from, lexemes, embarrassingly, and, weyl, mahommed,
# Nearest to it: to, rstendamm, prohibit, sequestration, troublesome, got, preterite, hermas,
# Nearest to as: for, microorganisms, of, deems, macroscopic, by, ammonites, following,
# Nearest to history: weblog, athletic, aegeas, yad, readme, monophysite, empire, koine,
# Nearest to he: had, him, winchilsea, stint, qutb, his, fate, noticed,
# Nearest to world: doubleday, recruiting, tendency, cricinfo, deny, tournament, champion, cri,
# Nearest to s: sex, lockhart, promoting, reprinting, voyager, slugged, declarer, spidey,
# Nearest to a: an, of, the, on, vaud, compressible, iix, can,
# Nearest to applications: general, manage, apps, thumbnail, pda, app, coursework, debug,
# Nearest to orthodox: catholic, greyface, rallied, jm, trumped, noriega, ecumenism, hermaphrodite,
# Nearest to brother: daughter, ircs, frown, son, beloved, marry, widow, explicated,
# Nearest to centre: pliny, reliability, hinterland, now, mined, overlooks, fcc, campuses,
# Nearest to know: you, get, myself, ll, proves, toil, foundational, ourselves,
# Nearest to notes: faq, textus, pires, sixths, octave, berlioz, chalukyas, robbins,
# Nearest to older: householder, household, versus, families, rit, mistranslation, posses, as,
# Nearest to running: minter, unauthorised, esat, samsung, linebackers, level, overstepped, contract,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0165 0.0140 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9486 0.0137 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0509 0.0140 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0361 0.0135 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0058 0.0133 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0256 0.0139 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9234 0.0140 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9414 0.0133 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9353 0.0133 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9843 0.0138 sec/batch
# Nearest to an: a, magnetically, from, embarrassingly, lexemes, toluene, and, boson,
# Nearest to it: to, since, rstendamm, prohibit, esters, sequestration, troublesome, up,
# Nearest to as: for, microorganisms, of, macroscopic, unique, three, following, by,
# Nearest to history: weblog, athletic, aegeas, taunton, empire, spartacus, hosts, yad,
# Nearest to he: had, him, stint, fate, winchilsea, his, freewheelin, lansbury,
# Nearest to world: doubleday, recruiting, tendency, cri, cricinfo, champion, deny, tournament,
# Nearest to s: sex, lockhart, promoting, slugged, reprinting, musketeer, patrilineal, bricks,
# Nearest to a: an, of, the, can, on, in, compressible, iix,
# Nearest to applications: general, apps, manage, coursework, pda, app, thumbnail, debug,
# Nearest to orthodox: catholic, greyface, rallied, jm, trumped, ecumenism, noriega, adventists,
# Nearest to brother: daughter, ircs, frown, son, beloved, marry, explicated, widow,
# Nearest to centre: pliny, now, reliability, hinterland, ruins, mined, housing, streets,
# Nearest to know: get, you, myself, ll, proves, toil, doesn, foundational,
# Nearest to notes: faq, textus, pires, octave, sixths, strings, ensembles, berlioz,
# Nearest to older: householder, household, versus, families, mistranslation, macarius, rit, posses,
# Nearest to running: minter, esat, unauthorised, glans, lu, level, contract, overstepped,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9990 0.0140 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0108 0.0137 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9770 0.0131 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9765 0.0134 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0406 0.0137 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9566 0.0134 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0019 0.0138 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9753 0.0136 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9760 0.0136 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9793 0.0135 sec/batch
# Nearest to an: a, magnetically, from, lexemes, embarrassingly, toluene, pairwise, trivial,
# Nearest to it: to, since, prohibit, esters, hermas, esotericism, troublesome, rstendamm,
# Nearest to as: for, of, microorganisms, macroscopic, unique, by, three, greg,
# Nearest to history: weblog, aegeas, athletic, spartacus, empire, yad, readme, monophysite,
# Nearest to he: had, him, stint, freewheelin, lansbury, his, winchilsea, sinners,
# Nearest to world: doubleday, tendency, deny, champion, cricinfo, recruiting, tournament, cri,
# Nearest to s: lockhart, sex, of, reprinting, voyager, slugged, musketeer, promoting,
# Nearest to a: an, of, the, on, can, in, vaud, iix,
# Nearest to applications: general, manage, coursework, apps, superhighway, thumbnail, pda, app,
# Nearest to orthodox: catholic, greyface, rallied, trumped, jm, noriega, adventists, eastern,
# Nearest to brother: daughter, ircs, frown, son, beloved, cristina, marry, widow,
# Nearest to centre: pliny, reliability, now, objectives, hinterland, campuses, labor, fcc,
# Nearest to know: get, you, myself, ll, proves, toil, arithmetic, doesn,
# Nearest to notes: faq, textus, pires, sixths, chalukyas, stoic, octave, strings,
# Nearest to older: householder, household, versus, families, mistranslation, posses, rit, macarius,
# Nearest to running: minter, esat, unauthorised, glans, lu, level, samsung, overstepped,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0057 0.0137 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9812 0.0133 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9605 0.0135 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9838 0.0132 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0122 0.0137 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0184 0.0132 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9937 0.0142 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9528 0.0147 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9711 0.0132 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0331 0.0139 sec/batch
# Nearest to an: a, magnetically, from, and, lexemes, jpeg, embarrassingly, tokai,
# Nearest to it: to, since, troublesome, prohibit, hermas, esters, oca, sequestration,
# Nearest to as: for, of, microorganisms, by, macroscopic, unique, deems, following,
# Nearest to history: weblog, monophysite, aegeas, empire, athletic, yad, hellespont, taunton,
# Nearest to he: had, him, stint, his, freewheelin, lansbury, winchilsea, hoffmann,
# Nearest to world: doubleday, deny, tendency, recruiting, cri, tournament, fifa, champion,
# Nearest to s: lockhart, of, sex, guyana, voyager, promoting, reprinting, shasta,
# Nearest to a: an, of, the, can, in, on, vaud, every,
# Nearest to applications: general, manage, coursework, superhighway, apps, pda, dix, maniera,
# Nearest to orthodox: catholic, rallied, greyface, jm, trumped, adventists, noriega, religious,
# Nearest to brother: daughter, ircs, frown, son, cristina, beloved, explicated, marry,
# Nearest to centre: pliny, now, reliability, hinterland, labor, campuses, objectives, ruins,
# Nearest to know: you, get, myself, ll, proves, toil, doesn, apostolic,
# Nearest to notes: textus, faq, pires, strings, octave, sixths, chalukyas, instrumental,
# Nearest to older: householder, household, versus, families, mistranslation, posses, macarius, as,
# Nearest to running: esat, unauthorised, minter, glans, level, lu, maccabeus, overstepped,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9717 0.0148 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0797 0.0138 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0196 0.0138 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0655 0.0136 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9417 0.0134 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9490 0.0134 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 4.0059 0.0140 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9023 0.0139 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9929 0.0148 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9916 0.0139 sec/batch
# Nearest to an: a, magnetically, lexemes, from, and, tokai, for, jpeg,
# ...
# Nearest to notes: tender, textus, octave, sixths, reeds, saf, bending, strings,
# Nearest to older: householder, household, versus, under, three, families, alone, females,
# Nearest to running: minter, esat, glans, irrigate, offensive, into, linebackers, maccabeus,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8709 0.0142 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7630 0.0142 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8286 0.0139 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8055 0.0137 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8275 0.0145 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8335 0.0146 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8685 0.0139 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8332 0.0143 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8886 0.0138 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8978 0.0137 sec/batch
# Nearest to an: a, of, and, the, for, as, from, is,
# Nearest to it: is, to, of, its, a, not, the, that,
# Nearest to as: for, of, in, is, and, by, the, a,
# Nearest to history: article, links, interoperate, arising, taunton, era, recommended, monophysite,
# Nearest to he: his, had, him, freewheelin, career, asked, became, stint,
# Nearest to world: champion, doubleday, cri, series, commemorative, recruiting, deny, countries,
# Nearest to s: in, of, as, with, by, for, was, and,
# Nearest to a: an, of, the, is, in, and, as, to,
# Nearest to applications: manage, quizzes, buddy, maniera, conventional, app, general, latium,
# Nearest to orthodox: eastern, rallied, catholic, jm, galilean, spontaneity, noriega, baptizing,
# Nearest to brother: daughter, son, modules, mcfowl, widow, frown, barnett, marry,
# Nearest to centre: now, transferable, beltline, bristol, judaism, hinterland, labor, ruins,
# Nearest to know: you, myself, get, think, we, doesn, ll, didn,
# Nearest to notes: tender, textus, octave, sixths, strings, reeds, photosphere, bending,
# Nearest to older: householder, household, versus, under, alone, families, three, median,
# Nearest to running: minter, esat, glans, unauthorised, irrigate, level, coordinator, extreme,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8198 0.0139 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8642 0.0138 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8542 0.0142 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8549 0.0140 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8470 0.0142 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8740 0.0139 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8993 0.0149 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8389 0.0139 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8908 0.0140 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8761 0.0136 sec/batch
# Nearest to an: a, of, and, the, from, for, as, is,
# Nearest to it: is, to, of, its, a, the, that, not,
# Nearest to as: of, for, in, by, is, and, the, which,
# Nearest to history: arising, article, links, historical, era, interoperate, monophysite, weblog,
# Nearest to he: his, him, had, career, freewheelin, became, doctorate, studied,
# Nearest to world: series, countries, champion, cricinfo, doubleday, atlases, deny, recruiting,
# Nearest to s: in, of, by, as, with, a, was, for,
# Nearest to a: an, of, the, in, is, and, which, as,
# Nearest to applications: manage, quizzes, maniera, buddy, apps, latium, undiscovered, tudes,
# Nearest to orthodox: eastern, rallied, jm, spontaneity, catholic, galilean, trumped, noriega,
# Nearest to brother: daughter, son, mcfowl, modules, widow, frown, marry, explicated,
# Nearest to centre: transferable, now, beltline, judaism, ruins, objectives, mitanni, bristol,
# Nearest to know: you, think, myself, get, we, didn, doesn, ll,
# Nearest to notes: tender, textus, octave, sixths, pires, ursine, strings, faq,
# Nearest to older: householder, household, versus, under, alone, families, median, three,
# Nearest to running: minter, esat, glans, unauthorised, megiddo, irrigate, extreme, coordinator,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8520 0.0144 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8472 0.0136 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8486 0.0137 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8570 0.0137 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9170 0.0137 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8326 0.0145 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9734 0.0140 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9004 0.0139 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9160 0.0141 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8182 0.0145 sec/batch
# Nearest to an: a, of, and, the, from, for, as, in,
# Nearest to it: to, is, of, its, the, that, not, was,
# Nearest to as: for, of, by, in, the, and, is, which,
# Nearest to history: article, arising, links, empire, interoperate, taunton, aegeas, monophysite,
# Nearest to he: his, him, had, became, career, worked, was, professor,
# Nearest to world: countries, series, champion, fridtjof, tournament, doubleday, development, cricinfo,
# Nearest to s: in, of, by, with, as, was, for, reprinting,
# Nearest to a: an, the, of, is, in, which, to, into,
# Nearest to applications: manage, quizzes, app, apps, maniera, latium, buddy, superhighway,
# Nearest to orthodox: rallied, eastern, jm, frames, galilean, noriega, ilya, simplifications,
# Nearest to brother: daughter, son, modules, barnett, mcfowl, widow, advisers, frown,
# Nearest to centre: now, transferable, bristol, beltline, london, ruins, judaism, mitanni,
# Nearest to know: you, think, myself, get, didn, we, ll, aware,
# Nearest to notes: tender, octave, textus, bending, sixths, reeds, saf, pires,
# Nearest to older: householder, household, versus, under, families, alone, three, have,
# Nearest to running: minter, esat, irrigate, glans, coordinator, extreme, unauthorised, joker,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8090 0.0144 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8853 0.0139 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7819 0.0150 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8460 0.0144 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8663 0.0138 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8485 0.0139 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9003 0.0076 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8328 0.0145 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8154 0.0147 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8683 0.0151 sec/batch
# Nearest to an: a, and, of, the, from, for, is, as,
# Nearest to it: is, to, the, its, a, of, was, that,
# Nearest to as: for, of, in, by, the, is, and, to,
# Nearest to history: article, links, arising, interoperate, monophysite, spartacus, recommended, desserts,
# Nearest to he: his, him, had, was, became, returned, to, after,
# Nearest to world: series, countries, champion, eradication, development, atlases, fridtjof, worldwide,
# Nearest to s: in, of, as, by, for, was, with, and,
# Nearest to a: an, the, of, in, is, and, to, as,
# Nearest to applications: manage, quizzes, maniera, latium, app, undiscovered, dix, conventional,
# Nearest to orthodox: eastern, rallied, jm, frames, ilya, noriega, galilean, billiards,
# Nearest to brother: daughter, son, modules, mcfowl, widow, advisers, neva, frown,
# Nearest to centre: now, transferable, beltline, bristol, london, objectives, hinterland, mitanni,
# Nearest to know: you, think, myself, get, we, didn, aware, ask,
# Nearest to notes: tender, octave, textus, sixths, reeds, bending, saf, pires,
# Nearest to older: householder, household, versus, alone, families, under, have, median,
# Nearest to running: minter, esat, glans, offensive, irrigate, back, coordinator, extreme,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8099 0.0139 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8068 0.0139 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8197 0.0150 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7968 0.0140 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8939 0.0146 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8340 0.0138 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8744 0.0137 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7227 0.0137 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8239 0.0142 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7950 0.0145 sec/batch
# Nearest to an: a, of, and, from, the, is, for, as,
# Nearest to it: is, to, of, a, its, the, not, that,
# Nearest to as: in, of, for, is, the, a, and, by,
# Nearest to history: article, links, arising, interoperate, familycolor, historical, desserts, taunton,
# Nearest to he: his, him, had, became, was, asked, career, returned,
# Nearest to world: series, countries, atlases, champion, cri, robotech, deluded, development,
# Nearest to s: in, of, as, by, with, was, for, and,
# Nearest to a: an, of, the, is, in, as, and, which,
# Nearest to applications: quizzes, manage, maniera, latium, app, dix, undiscovered, granules,
# Nearest to orthodox: eastern, rallied, jm, frames, billiards, ilya, catholic, pigeonhole,
# Nearest to brother: son, daughter, mcfowl, modules, neva, widow, advisers, marry,
# Nearest to centre: now, transferable, beltline, bristol, judaism, pliny, ruins, london,
# Nearest to know: you, think, myself, get, we, didn, ask, doesn,
# Nearest to notes: tender, textus, octave, reeds, bending, sixths, provenance, saf,
# Nearest to older: householder, household, alone, versus, families, under, three, have,
# Nearest to running: esat, minter, irrigate, glans, extreme, coordinator, multipliers, joker,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7299 0.0153 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8372 0.0147 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8342 0.0146 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8318 0.0134 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8080 0.0150 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9116 0.0142 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8387 0.0139 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8221 0.0134 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8278 0.0138 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8632 0.0143 sec/batch
# Nearest to an: a, of, from, and, the, is, for, as,
# Nearest to it: is, to, its, the, of, not, that, in,
# Nearest to as: of, for, in, is, the, by, and, a,
# Nearest to history: article, links, arising, encyclopedia, interoperate, era, aegeas, recommended,
# Nearest to he: his, him, had, career, became, freewheelin, returned, asked,
# Nearest to world: series, countries, cri, perfection, champion, fridtjof, goodwill, correspondents,
# Nearest to s: in, of, as, for, with, a, by, and,
# Nearest to a: an, of, the, in, is, which, to, and,
# Nearest to applications: manage, quizzes, maniera, latium, app, dix, undiscovered, granules,
# Nearest to orthodox: eastern, catholic, rallied, jm, patriarchs, orthodoxy, galilean, patriarchate,
# Nearest to brother: son, daughter, modules, mcfowl, widow, cristina, barnett, neva,
# Nearest to centre: transferable, now, beltline, bristol, objectives, judaism, revolves, privacy,
# Nearest to know: you, think, myself, get, we, didn, cherry, doesn,
# Nearest to notes: tender, textus, octave, saf, ursine, pires, provenance, sixths,
# Nearest to older: householder, household, versus, alone, families, under, median, age,
# Nearest to running: esat, minter, coach, extreme, coordinator, glans, irrigate, offensive,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8783 0.0142 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8707 0.0147 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8184 0.0148 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8461 0.0142 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8888 0.0136 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8496 0.0135 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8209 0.0141 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8375 0.0140 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8241 0.0134 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8248 0.0134 sec/batch
# Nearest to an: a, of, from, is, the, and, as, for,
# Nearest to it: to, is, the, its, was, of, that, even,
# Nearest to as: for, of, in, and, is, by, the, which,
# Nearest to history: links, article, historical, arising, era, encyclopedia, archontology, recommended,
# Nearest to he: his, him, had, became, career, asked, semmelweis, professor,
# Nearest to world: countries, series, atlases, champion, doubleday, one, correspondents, fridtjof,
# Nearest to s: of, in, by, with, as, for, a, and,
# Nearest to a: an, of, the, in, is, which, and, as,
# Nearest to applications: manage, quizzes, app, dix, gnutella, maniera, buddy, centric,
# Nearest to orthodox: eastern, rallied, catholic, galilean, frames, jm, patriarchate, patriarchs,
# Nearest to brother: son, daughter, modules, mcfowl, rumpus, widow, barnett, cristina,
# Nearest to centre: now, transferable, beltline, bristol, london, judaism, objectives, revolves,
# Nearest to know: you, think, we, get, myself, didn, aware, doesn,
# Nearest to notes: tender, octave, textus, bending, note, reeds, strings, provenance,
# Nearest to older: householder, household, versus, alone, families, under, three, median,
# Nearest to running: esat, minter, extreme, glans, coach, irrigate, coordinator, megiddo,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8536 0.0142 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8267 0.0134 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9317 0.0148 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9250 0.0136 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8937 0.0137 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8549 0.0141 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7625 0.0135 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8452 0.0128 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7231 0.0140 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8662 0.0144 sec/batch
# Nearest to an: a, of, the, and, from, as, is, for,
# Nearest to it: is, to, its, the, was, but, that, of,
# Nearest to as: for, of, in, the, by, and, is, which,
# Nearest to history: article, links, arising, era, abencerrages, historical, encyclopedia, interoperate,
# Nearest to he: his, him, had, worked, career, became, professor, was,
# Nearest to world: countries, fridtjof, doubleday, champion, series, nine, one, eradication,
# Nearest to s: in, of, with, by, as, for, and, was,
# Nearest to a: an, of, the, is, in, which, as, and,
# Nearest to applications: manage, quizzes, app, apps, hashes, gnutella, dix, latium,
# Nearest to orthodox: eastern, rallied, galilean, frames, billiards, jm, staking, chinatown,
# Nearest to brother: son, daughter, mcfowl, modules, barnett, rumpus, neva, advisers,
# Nearest to centre: now, transferable, beltline, bristol, london, judaism, objectives, brick,
# Nearest to know: think, you, get, we, didn, aware, myself, doesn,
# Nearest to notes: tender, octave, textus, provenance, bending, reeds, saf, ursine,
# Nearest to older: householder, household, versus, under, alone, families, three, formations,
# Nearest to running: esat, minter, extreme, coordinator, coach, glans, irrigate, multipliers,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8497 0.0144 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8331 0.0131 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
# Out:
# /home/alok/anaconda3/envs/dlnd/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/alok/anaconda3/envs/dlnd/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
